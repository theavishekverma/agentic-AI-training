# %% [markdown]
# # Python API - Requests Library

# %% [markdown]
# # Get Endpoint

# %%
import requests

url = "https://jsonplaceholder.typicode.com/todos/2"

response = requests.get(url)
if response.status_code == 200:
    print("Request successful!")
    print(response.json())
    print(response.headers)
    print(response.text)
else:
    print("Request failed!")
# Out:
# Request successful!
# {'userId': 1, 'id': 2, 'title': 'quis ut nam facilis et officia qui', 'completed': False}
# ...

# %% [markdown]
# # Post Endpoint

# %%
import requests
import json

url = "https://jsonplaceholder.typicode.com/posts"

data = {
    "title":"foo",
    "body":"far",
    "userId":"1"
}

headers = { "Content-Type": "application/json" }
response = requests.post(url, data=json.dumps(data), headers=headers)
print(response.status_code)
print(response.json())
# Out:
# 201
# {'title': 'foo', 'body': 'far', 'userId': '1', 'id': 101}

# %% [markdown]
# # PUT Endpoint

# %%
import requests
import json

url = "https://jsonplaceholder.typicode.com/posts/2"

data = {
    "id": 2,
    "title": "Python Student",
    "body": "Vishal",
    "userId": "1",
}

headers = { "Content-Type": "application/json" }

response = requests.put(url, data=json.dumps(data), headers=headers)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'id': 2, 'title': 'Python Student', 'body': 'Vishal', 'userId': '1'}

# %% [markdown]
# # Delete Endpoint

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts/2"
response = requests.delete(url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Open API Key - Call ChatGPT API

# %%
import requests
import os
OPENAI_API_KEY ="sk-proj-9_lfx_GA_MXk-"
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.5",
    input="How i can call openai api in python without using SDK and give me entite code with example"
)

print(response.output_text)
# Out:
# Yes — you can call the OpenAI API in Python **without using the OpenAI SDK** by sending normal HTTP requests.
#
# Below is a complete working example using `requests`.
#
# ---
#
# ## 1. Install `requests`
#
# ```bash
# pip install requests
# ```
#
# ---
#
# ## 2. Set your API key
#
# ### macOS / Linux
#
# ```bash
# export OPENAI_API_KEY="your_api_key_here"
# ```
#
# ### Windows PowerShell
#
# ```powershell
# setx OPENAI_API_KEY "your_api_key_here"
# ```
#
# Restart your terminal after running `setx`.
#
# ---
#
# ## 3. Complete Python code
#
# Create a file named `openai_api_no_sdk.py`:
#
# ```python
# import os
# import requests
# import json
#
#
# def extract_text(response_json):
#     """
#     Extracts text from the OpenAI Responses API response.
#     """
#     if "output_text" in response_json:
#         return response_json["output_text"]
#
#     text_parts = []
#
#     for item in response_json.get("output", []):
#         for content in item.get("content", []):
# ...

# %% [markdown]
# # Calling ChatGPT API and passing OPENAPI Key in Header

# %%
import requests
import json

API_KEY = "sk-proj-"

url = "https://api.openai.com/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

payload = {
    "model": "gpt-4.1-mini",
    "messages": [
        {
            "role": "system",
            "content": "You are a helpful assistant."
        },
        {
            "role": "user",
            "content": "Explain Python API in simple words."
        }
    ],
    "temperature": 0.7
}

response = requests.post(
    url,
    headers=headers,
    json=payload
)

print("Status Code:", response.status_code)
print(json.dumps(response.json(), indent=2))
# Out:
# Status Code: 200
# {
#   "id": "chatcmpl-DiwL5a4P9BqjIlZZHSB2CPqkS8o5I",
#   "object": "chat.completion",
#   "created": 1779603059,
#   "model": "gpt-4.1-mini-2025-04-14",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Sure! \n\nA Python API is a way for different software programs to talk to each other using the Python programming language. \n\n\"API\" stands for Application Programming Interface. It\u2019s like a set of rules or instructions that lets one program use features or data from another program without needing to know how that other program works inside.\n\nFor example, if you use a Python API to get weather information from a website, your Python code sends a request following the API\u2019s rules, and the website sends back the weather data so your program can use it.\n\nIn short, a Python API lets your Python program easily connect and interact with other software or services.",
# ...

# %% [markdown]
# # Params In API

# %%
import requests

url = "https://api.open-meteo.com/v1/forecast?latitude=5.52&longitude=13.41&hourly=temperature_2m"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"latitude":5.5184536,"longitude":13.432836,"generationtime_ms":0.6937980651855469,"utc_offset_seconds":0,"timezone":"GMT","timezone_abbreviation":"GMT","elevation":696.0,"hourly_units":{"time":"iso8601","temperature_2m":"°C"},"hourly":{"time":["2026-05-24T00:00","2026-05-24T01:00","2026-05-24T02:00","2026-05-24T03:00","2026-05-24T04:00","2026-05-24T05:00","2026-05-24T06:00","2026-05-24T07:00","2026-05-24T08:00","2026-05-24T09:00","2026-05-24T10:00","2026-05-24T11:00","2026-05-24T12:00","2026-05-24T13:00","2026-05-24T14:00","2026-05-24T15:00","2026-05-24T16:00","2026-05-24T17:00","2026-05-24T18:00","2026-05-24T19:00","2026-05-24T20:00","2026-05-24T21:00","2026-05-24T22:00","2026-05-24T23:00","2026-05-25T00:00","2026-05-25T01:00","2026-05-25T02:00","2026-05-25T03:00","2026-05-25T04:00","2026-05-25T05:00","2026-05-25T06:00","2026-05-25T07:00","2026-05-25T08:00","2026-05-25T09:00","2026-05-25T10:00","2026-05-25T11:00","2026-05-25T12:00","2026-05-25T13:00","2026-05-25T14:00","2026-05-25T
# ...
