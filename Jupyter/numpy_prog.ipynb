# %%
import numpy as np numbers = [1, 2, 3, 4, 5] arr = np.array(numbers) # Single dimensional array a = np.array([1, 2, 3, 4, 5]) b = np.array([6, 7, 8, 9, 10]) print(a) print(b) print("Addition of a and b:", a + b)  # Element-wise addition print("Multiplication of a and b:", a * b) print("Subtraction of a and b:", a - b)  # Element-wise subtraction print("Division of a and b:", a / b)  # Element-wise division
# Out:
#   Cell In[1], line 1
#     import numpy as np numbers = [1, 2, 3, 4, 5] arr = np.array(numbers) # Single dimensional array a = np.array([1, 2, 3, 4, 5]) b = np.array([6, 7, 8, 9, 10]) print(a) print(b) print("Addition of a and b:", a + b)  # Element-wise addition print("Multiplication of a and b:", a * b) print("Subtraction of a and b:", a - b)  # Element-wise subtraction print("Division of a and b:", a / b)  # Element-wise division
#                     ^
# SyntaxError: cannot use name as import target
