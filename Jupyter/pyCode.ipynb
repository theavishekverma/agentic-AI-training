# %%
a = 7
b = 8
result = a + b
print("Sum:", result)
# Out:
# Sum: 15

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [29, 30, 39]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   29
# 1      Bob   30
# 2  Charlie   39
